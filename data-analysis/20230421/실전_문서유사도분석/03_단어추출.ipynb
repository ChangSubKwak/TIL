# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#작업폴도로 이동
# %cd /content/drive/MyDrive/ys/최종 문서유사도
# Out:
# /content/drive/MyDrive/_영숙님/최종 문서유사도

# %%
pwd
# Out:
# '/content/drive/MyDrive/ys/최종 문서유사도'

# %%
# konlpy, Mecab 형태소 분석기 설치 스크립트 실행
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
#코랩에서 plt 한글 깨짐 해결
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# 위의 모듈 설치 후 메뉴[런타임-런타임 다시 시작]을 해야 함

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore') 

path = 'NanumGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)
fm._rebuild()

# %%
from konlpy.tag import Okt, Mecab
import pandas as pd
import numpy as np
import seaborn as sns
#워드 클라우드
from wordcloud import WordCloud

mecab = Mecab()

# %%
df=pd.read_csv('./total_reault.csv')
df.head()
# Out:
#         날짜                title  \
# 0  2020-01  전세대출 하려는데 위험한지 봐주세요
# 1  2020-01        부동산문의 내공(100)
# 2  2020-01       전세보증금 못 받고 있어요
# 3  2020-01       전세보증금 못 받고 있어요
# 4  2020-01       전세보증금 못 받고 있어요
#
#                                            questions  \
# 0  청년 맞춤형 전세대출 하려는데 근저당 채권최고액이 1억 5천인데 전세금 6500인데...
# 1  4,000만원/324,000(1순위)4,000만원/280,000(2순위, 선순위대출...
# 2  계약기간 종료 3개월전 메세지 전달.내용증명 2차례 발송하였으나 반송.현재 계약기간...
# 3  계약기간 종료 3개월전 메세지 전달.내용증명 2차례 발송하였으나 반송.현재 계약기간...
# 4  계약기간 종료 3개월전 메세지 전달.내용증명 2차례 발송하였으나 반송.현재 계약기간...
#
#                                               answer  \
# 0  먼저 시세를 아셔야해요.​시세의 70% > (근저당+선순위보증금총액+본인보증금) ​...
# 1  최소 - 초등학교 산수 시간에 공부 안하신 분- 고등학교 법과정치 시간에 수업 안 ...
# 2  금액이 매우 크시네요.​더 이상을 시간 지체 하지마시고, 소송 하시는걸 추천해드립니...
# 3  적은 금액이 아니어서 몇달간 마음고생이 많으셨겠습니다지금 진행된 상황이 아파트를 이...
# 4  ​​ 합의가 안되면,민사 보증금반환청구소송을 해야합니다.소제기후 사실조회로 상대방의...
#
#                                      title_questions
# 0  전세대출 하려는데 위험한지 봐주세요_청년 맞춤형 전세대출 하려는데 근저당 채권최고액...
# 1  부동산문의 내공(100)_4,000만원/324,000(1순위)4,000만원/280,...
# 2  전세보증금 못 받고 있어요_계약기간 종료 3개월전 메세지 전달.내용증명 2차례 발송...
# 3  전세보증금 못 받고 있어요_계약기간 종료 3개월전 메세지 전달.내용증명 2차례 발송...
# 4  전세보증금 못 받고 있어요_계약기간 종료 3개월전 메세지 전달.내용증명 2차례 발송...

# %% [markdown]
# # 명사 추출

# %% [markdown]
# ## 1. questions에서 명사 추출

# %%
#제목에서 명사 추출
nouns=[mecab.nouns(i) for i in df['questions']]
# 문서별 제목 명사 추출 pickle로 저장

import pickle
with open('nouns_questions.pickle', 'wb') as f:
    pickle.dump(nouns, f, pickle.HIGHEST_PROTOCOL)

# %%
nouns[:10]
# Out:
# [['청년',
#   '맞춤',
#   '전세',
#   '대출',
#   '근저당',
#   '채권',
#   '최고액',
#   '억',
#   '천',
#   '전세금',
#   '청년',
#   '맞춤',
#   '대출',
#   '보증',
#   '보험',
#   '가입',
#   '거',
#   '나중',
#   '경매',
#   '위험'],
#  ['만',
#   '원',
#   '순위',
#   '만',
#   '원',
#   '순위',
#   '선순위',
#   '대출',
#   '유',
#   '오피스',
#   '켈',
#   '매물',
#   '이게',
#   '의미',
#   '추가',
#   '정보',
#   '위험'],
#  ['계약',
#   '기간',
#   '종료',
#   '개월',
#   '전',
#   '메세지',
#   '전달',
#   '내용증명',
#   '차례',
#   '발송',
#   '반송',
#   '계약',
#   '기간',
#   '종료',
#   '아파트',
#   '보증금',
#   '칠',
#   '천만',
#   '원',
#   '집',
#   '주인',
#   '칠',
#   '천만',
#   '원',
#   '매매',
#   '집',
#   '돈',
#   '전세금',
#   '이사',
#   '예정',
#   '임대차',
#   '등기',
#   '명령',
#   '신청',
#   '후',
#   '송달',
#   '중',
#   '참고',
#   '집',
#   '주인',
#   '임대업',
#   '깡통',
#   '전세',
#   '것',
#   '데',
#   '전세금',
#   '아파트',
#   '방법',
#   '건가요',
#   '집',
#   '경매',
#   '것',
#   '방법',
#   '저',
#   '아파트',
#   '외곽',
#   '아파트',
#   '매매',
#   '것',
#   '소송',
#   '생각',
#   '중',
#   '등기',
#   '완료',
#   '후',
#   '지급',
#   '명령',
#   '신청',
#   '소송',
#   '순서',
#   '가압류',
#   '신청',
#   '것',
#   '순서',
#   '집',
#   '경매',
#   '제',
#   '집',
#   '낙찰',
#   '제',
#   '돈',
#   '게',
#   '상계',
#   '처리',
#   '세금',
#   '것',
#   '제',
#   '이야기'],
#  ['계약',
#   '기간',
#   '종료',
#   '개월',
#   '전',
#   '메세지',
#   '전달',
#   '내용증명',
#   '차례',
#   '발송',
#   '반송',
#   '계약',
#   '기간',
#   '종료',
#   '아파트',
#   '보증금',
#   '칠',
#   '천만',
#   '원',
#   '집',
#   '주인',
#   '칠',
#   '천만',
#   '원',
#   '매매',
#   '집',
#   '돈',
#   '전세금',
#   '이사',
#   '예정',
#   '임대차',
#   '등기',
#   '명령',
#   '신청',
#   '후',
#   '송달',
#   '중',
#   '참고',
#   '집',
#   '주인',
#   '임대업',
#   '깡통',
#   '전세',
#   '것',
#   '데',
#   '전세금',
#   '아파트',
#   '방법',
#   '건가요',
#   '집',
#   '경매',
#   '것',
#   '방법',
#   '저',
#   '아파트',
#   '외곽',
#   '아파트',
#   '매매',
#   '것',
#   '소송',
#   '생각',
#   '중',
#   '등기',
#   '완료',
#   '후',
#   '지급',
#   '명령',
#   '신청',
#   '소송',
#   '순서',
#   '가압류',
#   '신청',
#   '것',
#   '순서',
#   '집',
#   '경매',
#   '제',
#   '집',
#   '낙찰',
#   '제',
#   '돈',
#   '게',
#   '상계',
#   '처리',
#   '세금',
#   '것',
#   '제',
#   '이야기'],
#  ['계약',
#   '기간',
#   '종료',
#   '개월',
#   '전',
#   '메세지',
#   '전달',
#   '내용증명',
#   '차례',
#   '발송',
#   '반송',
#   '계약',
#   '기간',
#   '종료',
#   '아파트',
#   '보증금',
#   '칠',
#   '천만',
#   '원',
#   '집',
#   '주인',
#   '칠',
#   '천만',
#   '원',
#   '매매',
#   '집',
#   '돈',
#   '전세금',
#   '이사',
#   '예정',
#   '임대차',
#   '등기',
#   '명령',
#   '신청',
#   '후',
#   '송달',
#   '중',
#   '참고',
#   '집',
#   '주인',
#   '임대업',
#   '깡통',
#   '전세',
#   '것',
#   '데',
#   '전세금',
#   '아파트',
#   '방법',
#   '건가요',
#   '집',
#   '경매',
#   '것',
#   '방법',
#   '저',
#   '아파트',
#   '외곽',
#   '아파트',
#   '매매',
#   '것',
#   '소송',
#   '생각',
#   '중',
#   '등기',
#   '완료',
#   '후',
#   '지급',
#   '명령',
#   '신청',
#   '소송',
#   '순서',
#   '가압류',
#   '신청',
#   '것',
#   '순서',
#   '집',
#   '경매',
#   '제',
#   '집',
#   '낙찰',
#   '제',
#   '돈',
#   '게',
#   '상계',
#   '처리',
#   '세금',
#   '것',
#   '제',
#   '이야기'],
#  ['안녕',
#   '새해',
#   '복',
#   '년',
#   '간',
#   '집',
#   '주인',
#   '사기',
#   '깡통',
#   '전세',
#   '보증금',
#   '길',
#   '전자',
#   '소송',
#   '후',
#   '강제',
#   '경매',
#   '중',
#   '제',
#   '순위',
#   '사람',
#   '경매',
#   '것',
#   '차',
#   '제',
#   '입찰',
#   '첨부',
#   '파일',
#   '강제',
#   '경매',
#   '매각',
#   '기일',
#   '통지서',
#   '사건',
#   '번호',
#   '타경',
#   '본인',
#   '순위',
#   '채권자',
#   '경매',
#   '신청자',
#   '차',
#   '경매',
#   '입찰',
#   '금액',
#   '최고',
#   '낙찰',
#   '저',
#   '남',
#   '입찰',
#   '것',
#   '차',
#   '매각',
#   '최저',
#   '가격',
#   '이',
#   '대',
#   '것',
#   '제',
#   '순위',
#   '채권자',
#   '경매',
#   '신청자',
#   '누가',
#   '낙찰',
#   '제',
#   '전세',
#   '보증금',
#   '수',
#   '전세',
#   '보증금',
#   '천',
#   '백만',
#   '손해',
#   '입찰',
#   '가격',
#   '세',
#   '포함',
#   '글',
#   '데',
#   '얼마',
#   '것',
#   '경매',
#   '참여시',
#   '보증금',
#   '제외',
#   '나머지',
#   '금액',
#   '전세',
#   '보증금',
#   '상계',
#   '처리',
#   '방식',
#   '절차',
#   '전세',
#   '보증금',
#   '상계',
#   '처리',
#   '것',
#   '제',
#   '차',
#   '번',
#   '금액',
#   '입찰',
#   '때',
#   '이후',
#   '발생',
#   '비용',
#   '것',
#   '정도',
#   '금액',
#   '취득세',
#   '등등',
#   '제',
#   '낙찰',
#   '후',
#   '년',
#   '안',
#   '양도세',
#   '데',
#   '매매',
#   '금액',
#   '전세금',
#   '천',
#   '백',
#   '거',
#   '건물',
#   '경매',
#   '낙찰가',
#   '예외',
#   '규정',
#   '경매',
#   '입찰',
#   '낙찰',
#   '후',
#   '이후',
#   '절차',
#   '부탁',
#   '신혼',
#   '반지하',
#   '전세',
#   '보증금',
#   '애',
#   '명',
#   '집',
#   '지식',
#   '도움',
#   '부탁',
#   '답변',
#   '감사',
#   '복',
#   '겁니다'],
#  ['안녕',
#   '고수',
#   '해답',
#   '현재',
#   '전세',
#   '확정',
#   '일자',
#   '집',
#   '주인',
#   '담보',
#   '대출',
#   '경매',
#   '전세',
#   '보증금',
#   '수'],
#  ['안녕',
#   '고수',
#   '해답',
#   '현재',
#   '전세',
#   '확정',
#   '일자',
#   '집',
#   '주인',
#   '담보',
#   '대출',
#   '경매',
#   '전세',
#   '보증금',
#   '수'],
#  ['안녕',
#   '고수',
#   '해답',
#   '현재',
#   '전세',
#   '확정',
#   '일자',
#   '집',
#   '주인',
#   '담보',
#   '대출',
#   '경매',
#   '전세',
#   '보증금',
#   '수'],
#  ['안녕',
#   '고수',
#   '해답',
#   '현재',
#   '전세',
#   '확정',
#   '일자',
#   '집',
#   '주인',
#   '담보',
#   '대출',
#   '경매',
#   '전세',
#   '보증금',
#   '수']]
