# %%
#!pip3 install --user mediapipe

# %%
import cv2
import mediapipe as mp
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# For static images:
# IMAGE_FILES = ['./open_cv.jpg'] # 이미지 파일 지정함
# IMAGE_FILES = ['./face.png', './img01.jpg'] # 이미지 파일 지정함

IMAGE_FILES = ['./multi-faces.jpg', './face.png', './beautiful-face.jpg'] # 이미지 파일 지정함

# model_selection 0 --> 근거리, 1 --> 원거리
# min_detection_confidence --> 최소 확률 50%

with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
  for idx, file in enumerate(IMAGE_FILES):
    print("index : {}".format(idx))
    image = cv2.imread(file)

    # Convert the BGR image to RGB and process it with MediaPipe Face Detection.
    results = face_detection.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    print("len(results.detections) : {}".format(len(results.detections)))

    # print(results.detections[0])
    # print(type(results.detections[0]))
    # print(type(results.detections))
    # print(results.detections)
    # continue

    # Draw face detections of each face.
    if not results.detections:
      continue
    annotated_image = image.copy()
    for detection in results.detections:
      print('Nose tip:')
      print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.NOSE_TIP))#코끝 감지
        
      print('오른쪽 눈:')
      print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.RIGHT_EYE))#오른쪽 눈
        
      print('왼쪽 눈:')
      print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.LEFT_EYE))# 왼쪽 눈
        
      print('입 중심:')
      print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.MOUTH_CENTER))#입 중심
        
      print('오른쪽 귀:')
      print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.RIGHT_EAR_TRAGION))#오른쪽 귀
        
      print('왼쪽 귀:')
      print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.LEFT_EAR_TRAGION))#왼쪽 귀



      
      mp_drawing.draw_detection(annotated_image, detection)
    cv2.imwrite('annotated_image' + str(idx) + '.jpg', annotated_image)
# Out:
# index : 0
# len(results.detections) : 9
# Nose tip:
# x: 0.6923791170120239
# y: 0.7945977449417114
#
# 오른쪽 눈:
# x: 0.6597007513046265
# y: 0.7594247460365295
#
# 왼쪽 눈:
# x: 0.7278982996940613
# y: 0.7559062838554382
#
# 입 중심:
# x: 0.6909016966819763
# y: 0.8288457989692688
#
# 오른쪽 귀:
# x: 0.6256746649742126
# y: 0.7858824729919434
#
# 왼쪽 귀:
# x: 0.770736813545227
# y: 0.785046398639679
#
# Nose tip:
# x: 0.3103528320789337
# y: 0.7995010018348694
#
# 오른쪽 눈:
# x: 0.27741438150405884
# y: 0.7565456628799438
#
# 왼쪽 눈:
# x: 0.3458417057991028
# y: 0.758520245552063
#
# 입 중심:
# x: 0.30692410469055176
# y: 0.8344066143035889
#
# 오른쪽 귀:
# x: 0.236697256565094
# y: 0.7788690328598022
#
# 왼쪽 귀:
# x: 0.383152574300766
# y: 0.7909232378005981
#
# Nose tip:
# x: 0.5021863579750061
# y: 0.8906933665275574
#
# 오른쪽 눈:
# x: 0.4654458165168762
# y: 0.8553035855293274
#
# 왼쪽 눈:
# x: 0.5381688475608826
# y: 0.8556841611862183
#
# 입 중심:
# x: 0.4968740940093994
# y: 0.9240383505821228
#
# 오른쪽 귀:
# x: 0.42573487758636475
# y: 0.8822224140167236
#
# 왼쪽 귀:
# x: 0.5749034285545349
# y: 0.8834256529808044
#
# Nose tip:
# x: 0.5028870701789856
# y: 0.533008337020874
#
# 오른쪽 눈:
# x: 0.4692290425300598
# y: 0.4937041401863098
#
# 왼쪽 눈:
# x: 0.5400987863540649
# y: 0.49502456188201904
#
# 입 중심:
# x: 0.4991944134235382
# y: 0.567598819732666
#
# 오른쪽 귀:
# x: 0.43130624294281006
# y: 0.5158951878547668
#
# 왼쪽 귀:
# x: 0.5797604322433472
# y: 0.523739755153656
#
# Nose tip:
# x: 0.2340770661830902
# y: 0.5378788113594055
#
# 오른쪽 눈:
# x: 0.20019541680812836
# y: 0.4891830086708069
#
# 왼쪽 눈:
# x: 0.2702018618583679
# y: 0.4924830198287964
#
# 입 중심:
# x: 0.23330241441726685
# y: 0.5741323828697205
#
# 오른쪽 귀:
# x: 0.1652410924434662
# y: 0.5121737718582153
#
# 왼쪽 귀:
# x: 0.31225651502609253
# y: 0.5169087648391724
#
# Nose tip:
# x: 0.5019752979278564
# y: 0.17128008604049683
#
# 오른쪽 눈:
# x: 0.4647703170776367
# y: 0.1255260705947876
#
# 왼쪽 눈:
# x: 0.5373639464378357
# y: 0.12439051270484924
#
# 입 중심:
# x: 0.4996548593044281
# y: 0.20730061829090118
#
# 오른쪽 귀:
# x: 0.4211569130420685
# y: 0.14160548150539398
#
# 왼쪽 귀:
# x: 0.5771651268005371
# y: 0.14404858648777008
#
# Nose tip:
# x: 0.6934094429016113
# y: 0.27199071645736694
#
# 오른쪽 눈:
# x: 0.6602650284767151
# y: 0.23068581521511078
#
# 왼쪽 눈:
# x: 0.725657045841217
# y: 0.22956214845180511
#
# 입 중심:
# x: 0.6921418905258179
# y: 0.30672532320022583
#
# 오른쪽 귀:
# x: 0.6206103563308716
# y: 0.24856670200824738
#
# 왼쪽 귀:
# x: 0.7637354731559753
# y: 0.25090157985687256
#
# Nose tip:
# x: 0.7694687247276306
# y: 0.5261557698249817
#
# 오른쪽 눈:
# x: 0.7366903424263
# y: 0.4914783835411072
#
# 왼쪽 눈:
# x: 0.8069164156913757
# y: 0.4910089373588562
#
# 입 중심:
# x: 0.7705509066581726
# y: 0.5659769177436829
#
# 오른쪽 귀:
# x: 0.7043570876121521
# y: 0.5291340351104736
#
# 왼쪽 귀:
# x: 0.8539336919784546
# y: 0.5277441143989563
#
# Nose tip:
# x: 0.30167409777641296
# y: 0.270721435546875
#
# 오른쪽 눈:
# x: 0.2700880467891693
# y: 0.22891373932361603
#
# 왼쪽 눈:
# x: 0.33949577808380127
# y: 0.23027770221233368
#
# 입 중심:
# x: 0.30167293548583984
# y: 0.30747032165527344
#
# 오른쪽 귀:
# x: 0.23342451453208923
# y: 0.25152552127838135
#
# 왼쪽 귀:
# x: 0.3835896849632263
# y: 0.2577477693557739
#
# index : 1
# len(results.detections) : 1
# Nose tip:
# x: 0.4939194619655609
# y: 0.4905667304992676
#
# 오른쪽 눈:
# x: 0.423075795173645
# y: 0.3676028847694397
#
# 왼쪽 눈:
# x: 0.5766211748123169
# y: 0.3681798577308655
#
# 입 중심:
# x: 0.493419885635376
# y: 0.5817136168479919
#
# 오른쪽 귀:
# x: 0.34817957878112793
# y: 0.40603774785995483
#
# 왼쪽 귀:
# x: 0.661899983882904
# y: 0.40950512886047363
#
# index : 2
# len(results.detections) : 1
# Nose tip:
# x: 0.453767329454422
# y: 0.518665075302124
#
# 오른쪽 눈:
# x: 0.34969526529312134
# y: 0.29820889234542847
#
# 왼쪽 눈:
# x: 0.5881713628768921
# y: 0.3246898055076599
#
# 입 중심:
# x: 0.4453895688056946
# y: 0.6807283759117126
#
# 오른쪽 귀:
# x: 0.23900103569030762
# y: 0.36717933416366577
#
# 왼쪽 귀:
# x: 0.7114197611808777
# y: 0.43513113260269165

# %%
pwd
# Out:
# 'C:\\Users\\hmh\\Documents\\py\\_이미지\\mediapipe'

# %%
for detection in results.detections:
    print(detection.location_data.relative_bounding_box)
    print('Nose tip:')
    print(mp_face_detection.get_key_point(detection, mp_face_detection.FaceKeyPoint.NOSE_TIP))
    mp_drawing.draw_detection(annotated_image, detection)
